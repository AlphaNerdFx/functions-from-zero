# %% [markdown]
# <a href="https://colab.research.google.com/github/AlphaNerdFx/functions-from-zero/blob/main/Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning Statements

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Variables

# %%
variable=1

# %%
x = 1
y = 2
x + y
# Out:
# 3

# %% [markdown]
# # Lists

# %%
my_list = [1,2,3]
my_list[0], my_list[1], my_list[2]
# Out:
# (1, 2, 3)

# %% [markdown]
# # Dictionary

# %%
my_dict = {1:"one", 2:"two"}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict.keys()
# Out:
# dict_keys([1, 2])

# %%
my_dict.values()
# Out:
# dict_values(['one', 'two'])

# %% [markdown]
# # Loops

# %%
for k,v in my_dict.items():
    print(k,v)
# Out:
# 1 one
# 2 two

# %%
for items in my_list:
    print(items)
# Out:
# 1
# 2
# 3
